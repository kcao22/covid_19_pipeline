# %%
# Instantiate Athena client connection
athena = session.client('athena')
# Instantiate S3 client connection
s3 = session.client('s3')

# %%
s3 = session.client('s3')
# s3.list_objects(Bucket='kc-covid-project')['ResponseMetadata']['HTTPStatusCode']
s3.list_objects(Bucket='kc-covid-project')
# Out:
# {'ResponseMetadata': {'RequestId': 'P4EE2D37ACJJSM2V',
#   'HostId': 'QmpUR4e1+lqIikYMHkhzgKeD68u743kSJYM5+/K3NbrjEG2Ug3GWOY/ipi06vD7ubNQFewDW3T8=',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': 'QmpUR4e1+lqIikYMHkhzgKeD68u743kSJYM5+/K3NbrjEG2Ug3GWOY/ipi06vD7ubNQFewDW3T8=',
#    'x-amz-request-id': 'P4EE2D37ACJJSM2V',
#    'date': 'Sat, 27 May 2023 18:25:48 GMT',
#    'x-amz-bucket-region': 'us-west-2',
#    'content-type': 'application/xml',
#    'transfer-encoding': 'chunked',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 0},
#  'IsTruncated': False,
#  'Marker': '',
#  'Contents': [{'Key': 'athena_outputs/3d8f0e89-b23b-4aff-ae4f-23ef8329fc66.csv',
#    'LastModified': datetime.datetime(2023, 5, 22, 2, 13, 1, tzinfo=tzutc()),
#    'ETag': '"ca4e0cb07c443faf127273f0ce15c8c4"',
#    'Size': 15697,
#    'StorageClass': 'STANDARD',
#    'Owner': {'DisplayName': 'kevincao222',
#     'ID': '547facf9c00fd0081b9005e3f717742f7934c6e3bc4150d348a28247c92b915b'}},
# ...
